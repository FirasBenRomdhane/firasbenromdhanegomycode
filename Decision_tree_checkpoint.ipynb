# %%
import pandas as pd
data=pd.read_csv('titanic-passengers.csv',delimiter=';')
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data=data.drop("Cabin",axis=1)
data=data.drop("Ticket",axis=1)
data.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch     Fare Embarked
# 0      0  13.0000        S
# 1      0   7.6500        S
# 2      0   7.8542        S
# 3      4  21.0750        S
# 4      0  52.0000        S
# 5      0   7.9250        S
# 6      0  14.5000        S
# 7      2  15.7417        C
# 8      0   7.2500        S
# 9      0  26.0000        S

# %%
import math
data['Age'].fillna(round(data['Age'].mean()),inplace=True)
data['Embarked'].fillna('S',inplace=True)
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['Sex']=encoder.fit_transform(data['Sex'])
data['Survived']=encoder.fit_transform(data['Survived'])
data['Embarked']=encoder.fit_transform(data['Embarked'])
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    1  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                              Jensen, Mr. Hans Peder    1  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                              Davidson, Mr. Thornton    1  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    1  37.0      2
# 6                                Patchett, Mr. George    1  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")    0   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    1  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...    0  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    1  25.0      0
# 11                                Haas, Miss. Aloisia    0  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)    0  48.0      1
# 13                            Chapman, Mr. John Henry    1  37.0      1
# 14                                McMahon, Mr. Martin    1  30.0      0
# 15                         Kallio, Mr. Nikolai Erland    1  17.0      0
# 16                          Widener, Mr. Harry Elkins    1  27.0      0
# 17                               Elias, Mr. Joseph Jr    1  17.0      1
# 18                                 Hickman, Mr. Lewis    1  32.0      2
# 19                       Hoyt, Mr. Frederick Maxfield    1  38.0      1
#
#     Parch      Fare  Embarked
# 0       0   13.0000         2
# 1       0    7.6500         2
# 2       0    7.8542         2
# 3       4   21.0750         2
# 4       0   52.0000         2
# 5       0    7.9250         2
# 6       0   14.5000         2
# 7       2   15.7417         0
# 8       0    7.2500         2
# 9       0   26.0000         2
# 10      0   13.0000         2
# 11      0    8.8500         2
# 12      2   65.0000         2
# 13      0   26.0000         2
# 14      0    7.7500         1
# 15      0    7.1250         2
# 16      2  211.5000         0
# 17      1    7.2292         0
# 18      0   73.5000         2
# 19      0   90.0000         2

# %%
import seaborn as sns
import  matplotlib.pyplot as plt
g=sns.FacetGrid(data,row='Sex',col='Survived',height=2.2,aspect=1.6)
g.map(plt.hist,'Age',bins=20)
g.add_legend()

# %%
def plot_correlation_map( data ):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( data )
#This function is a manual execution of the correlation groupby operation showing the impact of each feature on one another.

# %%
data[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
data['Title']=data['Name'].str.split(pat=',').str.get(1).str.split(pat='.').str.get(0)
data.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch     Fare  Embarked Title
# 0    1  28.0      0      0  13.0000         2    Mr
# 1    1  25.0      0      0   7.6500         2    Mr
# 2    1  20.0      0      0   7.8542         2    Mr
# 3    0  29.0      0      4  21.0750         2   Mrs
# 4    1  31.0      1      0  52.0000         2    Mr

# %%
sns.countplot(x="Title",data=data)

# %%
g=sns.FacetGrid(data,row='Title',col='Survived',height=2.2,aspect=1.6)
g.map(plt.hist,'Sex')
g.add_legend()

# %%
Title_Dictionary = {

           "Title" : { "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
}
data.replace(Title_Dictionary, inplace=True, regex=True)
data.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          812         0       3
# 872          786         0       3
# 873           43         0       3
# 874           60         0       3
# 875          463         0       1
# 876          375         0       3
# 877          271         0       1
# 878          787         1       3
# 879          275         1       3
# 880          360         1       3
# 881          699         0       1
# 882          775         1       2
# 883          809         0       2
# 884          278         0       2
# 885          150         0       2
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 871                                  Lester, Mr. James    1  39.0      0
# 872                 Harmer, Mr. Abraham (David Lishin)    1  25.0      0
# 873                                Kraeff, Mr. Theodor    1  30.0      0
# 874                 Goodwin, Master. William Frederick    1  11.0      5
# 875                                  Gee, Mr. Arthur H    1  47.0      0
# 876                         Palsson, Miss. Stina Viola    0   3.0      3
# 877                              Cairns, Mr. Alexander    1  30.0      0
# 878                          Sjoblom, Miss. Anna Sofia    0  18.0      0
# 879                         Healy, Miss. Hanora "Nora"    0  30.0      0
# 880                  Mockler, Miss. Helen Mary "Ellie"    0  30.0      0
# 881                           Thayer, Mr. John Borland    1  49.0      1
# 882              Hocking, Mrs. Elizabeth (Eliza Needs)    0  54.0      1
# 883                                  Meyer, Mr. August    1  39.0      0
# 884                        Parkes, Mr. Francis "Frank"    1  30.0      0
# 885                  Byles, Rev. Thomas Roussel Davids    1  42.0      0
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1
# 887                              Sirayanian, Mr. Orsen    1  22.0      0
# 888                                Cacic, Miss. Marija    0  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  30.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.0      0
#
#      Parch      Fare  Embarked     Title
# 871      0   24.1500         2       Mrs
# 872      0    7.2500         2       Mrs
# 873      0    7.8958         0       Mrs
# 874      2   46.9000         2    Master
# 875      0   38.5000         2       Mrs
# 876      1   21.0750         2      Miss
# 877      0   31.0000         2       Mrs
# 878      0    7.4958         2      Miss
# 879      0    7.7500         1      Miss
# 880      0    7.8792         1      Miss
# 881      1  110.8833         0       Mrs
# 882      3   23.0000         2      Mrss
# 883      0   13.0000         2       Mrs
# 884      0    0.0000         2       Mrs
# 885      0   13.0000         2   Officer
# 886      0   30.0708         0      Mrss
# 887      0    7.2292         0       Mrs
# 888      0    8.6625         2      Miss
# 889      0    7.8958         2       Mrs
# 890      0   26.0000         2      Miss

# %%
g=sns.FacetGrid(data,row='Title',col='Survived',height=2.2,aspect=1.6)
g.map(plt.hist,'Sex')
g.add_legend()

# %%
data["FamilySize"]=data["Parch"]+data["SibSp"]
data.head(20)
#this feature isn't really useful in the current data set since it doesn't have any impact on whether someone surivved an accident or not
# Out:
#     PassengerId  Survived  Pclass  \
# 0           343         0       2
# 1            76         0       3
# 2           641         0       3
# 3           568         0       3
# 4           672         0       1
# 5           105         0       3
# 6           576         0       3
# 7           382         1       3
# 8           228         0       3
# 9           433         1       2
# 10          135         0       2
# 11          294         0       3
# 12          755         1       2
# 13          595         0       2
# 14          127         0       3
# 15          434         0       3
# 16          378         0       1
# 17          533         0       3
# 18          666         0       2
# 19          225         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    1  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                              Jensen, Mr. Hans Peder    1  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                              Davidson, Mr. Thornton    1  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    1  37.0      2
# 6                                Patchett, Mr. George    1  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")    0   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    1  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...    0  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    1  25.0      0
# 11                                Haas, Miss. Aloisia    0  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)    0  48.0      1
# 13                            Chapman, Mr. John Henry    1  37.0      1
# 14                                McMahon, Mr. Martin    1  30.0      0
# 15                         Kallio, Mr. Nikolai Erland    1  17.0      0
# 16                          Widener, Mr. Harry Elkins    1  27.0      0
# 17                               Elias, Mr. Joseph Jr    1  17.0      1
# 18                                 Hickman, Mr. Lewis    1  32.0      2
# 19                       Hoyt, Mr. Frederick Maxfield    1  38.0      1
#
#     Parch      Fare  Embarked  Title  FamilySize
# 0       0   13.0000         2    Mrs           0
# 1       0    7.6500         2    Mrs           0
# 2       0    7.8542         2    Mrs           0
# 3       4   21.0750         2   Mrss           4
# 4       0   52.0000         2    Mrs           1
# 5       0    7.9250         2    Mrs           2
# 6       0   14.5000         2    Mrs           0
# 7       2   15.7417         0   Miss           2
# 8       0    7.2500         2    Mrs           0
# 9       0   26.0000         2   Mrss           1
# 10      0   13.0000         2    Mrs           0
# 11      0    8.8500         2   Miss           0
# 12      2   65.0000         2   Mrss           3
# 13      0   26.0000         2    Mrs           1
# 14      0    7.7500         1    Mrs           0
# 15      0    7.1250         2    Mrs           0
# 16      2  211.5000         0    Mrs           2
# 17      1    7.2292         0    Mrs           2
# 18      0   73.5000         2    Mrs           2
# 19      0   90.0000         2    Mrs           1

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

x=data.drop(["Survived", "Name","Title","Embarked"], axis=1)
y= data["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

treek = tree.DecisionTreeClassifier()  
treek.fit(x_train, y_train)   
y_pred=treek.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.776536312849162

# %%
#conda install python-graphviz

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data=export_graphviz(treek, out_file=None)
graph=graphviz.Source(dot_data)
graph.render("data")
graph

# %%
treek=tree.DecisionTreeClassifier(criterion="pruning",splitter='random',max_leaf_nodes=12,min_samples_leaf=7,max_depth=7)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

treek = tree.DecisionTreeClassifier()  
treek.fit(x_train, y_train)   
y_pred=treek.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7821229050279329

# %%
#as we add more depth and increase the leaf limit we can get better accuracy as long as we don't start overfitting

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
clf=RandomForestClassifier(n_estimators=10)  
clf.fit(x_train, y_train) 
y_pred=clf.predict(x_test) 
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8324022346368715

# %%
#random forest has a better accuracy than the decision forest since it limits the amount of detail we have which allows us to avoid overfitting
